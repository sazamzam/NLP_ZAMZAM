# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('./drive/MyDrive/Colab Notebooks/Reviews_Filter.csv')
# Out:
# Mounted at /content/drive

# %%
df.head(10)
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# 5   6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
# 6   7  B006K2ZZ7K  A1SP2KVKFXXRU1                David C. Sullivan
# 7   8  B006K2ZZ7K  A3JRGQVEQN31IQ               Pamela G. Williams
# 8   9  B000E7L2R4  A1MZYO9TZK0BBI                         R. James
# 9  10  B00171APVA  A21BT40VZCCYT4                    Carol A. Reed
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# ...

# %%
df.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Id                      14999 non-null  int64
#  1   ProductId               14999 non-null  object
#  2   UserId                  14999 non-null  object
#  3   ProfileName             14999 non-null  object
#  4   HelpfulnessNumerator    14999 non-null  int64
#  5   HelpfulnessDenominator  14999 non-null  int64
#  6   Score                   14999 non-null  int64
#  7   Time                    14999 non-null  int64
#  8   Summary                 14999 non-null  object
#  9   Text                    14999 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 1.1+ MB

# %%
df.set_index('Id', inplace=True)
df.head()
# Out:
#      ProductId          UserId                      ProfileName  \
# Id
# 1   B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 2   B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 3   B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 4   B000UA0QIQ  A395BORC6FGVXV                             Karl
# 5   B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#     HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# Id
# 1                      1                       1      5  1303862400
# 2                      0                       0      1  1346976000
# 3                      1                       1      4  1219017600
# 4                      3                       3      2  1307923200
# 5                      0                       0      5  1350777600
#
#                   Summary                                               Text
# Id
# 1   Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
df['time'] = pd.to_datetime(df['Time'])
df.drop(columns={'Time'}, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14999 entries, 1 to 14999
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ProductId               14999 non-null  object
#  1   UserId                  14999 non-null  object
#  2   ProfileName             14999 non-null  object
#  3   HelpfulnessNumerator    14999 non-null  int64
#  4   HelpfulnessDenominator  14999 non-null  int64
#  5   Score                   14999 non-null  int64
#  6   Summary                 14999 non-null  object
#  7   Text                    14999 non-null  object
#  8   time                    14999 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(5)
# memory usage: 1.1+ MB

# %%
df.head()
# Out:
#      ProductId          UserId                      ProfileName  \
# Id
# 1   B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 2   B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 3   B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 4   B000UA0QIQ  A395BORC6FGVXV                             Karl
# 5   B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#     HelpfulnessNumerator  HelpfulnessDenominator  Score  \
# Id
# 1                      1                       1      5
# 2                      0                       0      1
# 3                      1                       1      4
# 4                      3                       3      2
# 5                      0                       0      5
#
#                   Summary                                               Text  \
# Id
# 1   Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
df['Text'] = df['Text'].str.lower()
df.head()
# Out:
#      ProductId          UserId                      ProfileName  \
# Id
# 1   B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 2   B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 3   B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 4   B000UA0QIQ  A395BORC6FGVXV                             Karl
# 5   B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#     HelpfulnessNumerator  HelpfulnessDenominator  Score  \
# Id
# 1                      1                       1      5
# 2                      0                       0      1
# 3                      1                       1      4
# 4                      3                       3      2
# 5                      0                       0      5
#
#                   Summary                                               Text  \
# Id
# 1   Good Quality Dog Food  i have bought several of the vitality canned d...
# ...

# %%
import re
punct_re = r'[^\w\s\\n]'
regex = re.compile(punct_re, flags = re.IGNORECASE)
df['no_punc'] = df['Text'].replace(to_replace=regex, value=' ')

# %%
df['no_punc']
# Out:
# Id
# 1        i have bought several of the vitality canned d...
# 2        product arrived labeled as jumbo salted peanut...
# 3        this is a confection that has been around a fe...
# 4        if you are looking for the secret ingredient i...
# 5        great taffy at a great price   there was a wid...
#                                ...
# 14995    i ve been using the product in dishes that cal...
# 14996    could no longer find rice select whole wheat o...
# 14997    i discovered this in our local qfc grocery sto...
# 14998    hard to find whole wheat orzo in supermarket  ...
# 14999    this product is delicious  and healthier than ...
# Name: no_punc, Length: 14999, dtype: object

# %%
df.head(10)
# Out:
#      ProductId          UserId                      ProfileName  \
# Id
# 1   B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 2   B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 3   B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 4   B000UA0QIQ  A395BORC6FGVXV                             Karl
# 5   B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# 6   B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
# 7   B006K2ZZ7K  A1SP2KVKFXXRU1                David C. Sullivan
# 8   B006K2ZZ7K  A3JRGQVEQN31IQ               Pamela G. Williams
# 9   B000E7L2R4  A1MZYO9TZK0BBI                         R. James
# 10  B00171APVA  A21BT40VZCCYT4                    Carol A. Reed
#
#     HelpfulnessNumerator  HelpfulnessDenominator  Score  \
# Id
# 1                      1                       1      5
# 2                      0                       0      1
# 3                      1                       1      4
# ...

# %%
# !pip install bertopic
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 90 kB 3.7 MB/s
# ...
#      |████████████████████████████████| 636 kB 24.6 MB/s
# ...
#      |████████████████████████████████| 85 kB 4.6 MB/s
# ...
#      |████████████████████████████████| 88 kB 6.8 MB/s
# ...
#      |████████████████████████████████| 5.2 MB 44.7 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 5.5 MB 36.0 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 40.4 MB/s
# ...
#      |████████████████████████████████| 163 kB 55.9 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 31.2 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 52.1 MB/s
# ...
#   Created wheel for hdbscan: filename=hdbscan-0.8.29-cp37-cp37m-linux_x86_64.whl size=2340735 sha256=ac7164d612f5484826715ad17757c1bb0bb7aa570d82d5bf7b3f37cf70257201
# ...

# %%
#import packages

import pandas as pd 
import numpy as np
from bertopic import BERTopic

# %%
#load data 
import pandas as pd 
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('./drive/MyDrive/Colab Notebooks/Reviews_Filter.csv')
 
# select only 6000 tweets 
df = df[0:6000]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.head(10)
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# 5   6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
# 6   7  B006K2ZZ7K  A1SP2KVKFXXRU1                David C. Sullivan
# 7   8  B006K2ZZ7K  A3JRGQVEQN31IQ               Pamela G. Williams
# 8   9  B000E7L2R4  A1MZYO9TZK0BBI                         R. James
# 9  10  B00171APVA  A21BT40VZCCYT4                    Carol A. Reed
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# ...

# %%
# create model 
 
model = BERTopic(verbose=True)
 
#convert to list 
docs = df.Text.to_list()
 
topics, probabilities = model.fit_transform(docs)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Batches:   0%|          | 0/188 [00:00<?, ?it/s]
# 2022-11-08 07:52:38,628 - BERTopic - Transformed documents to Embeddings
# 2022-11-08 07:53:19,919 - BERTopic - Reduced dimensionality
# ...

# %%
model.get_topic_freq().head(11)
# Out:
#     Topic  Count
# 0      -1   1578
# 1       0    236
# 2       1    201
# 3       2    111
# 4       3    106
# 5       4    102
# 6       5    100
# 7       6     94
# 8       7     91
# 9       8     89
# 10      9     89

# %%
model.get_topic(0)
# Out:
# [('dog', 0.03748823956721374),
#  ('food', 0.03140878899904043),
#  ('newmans', 0.01875598438461767),
#  ('dogs', 0.0171055027528635),
#  ('her', 0.01418102602685903),
#  ('she', 0.013086681575398256),
#  ('he', 0.011140667272494777),
#  ('own', 0.010562048720369208),
#  ('his', 0.010220464596929718),
#  ('my', 0.009641289731797835)]

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model = BERTopic(nr_topics=30)

# %%
topics, probabilities = model.fit_transform(docs)
# Out:
# 2022-11-08 08:00:18,548 - BERTopic - Transformed documents to Embeddings
# 2022-11-08 08:00:35,839 - BERTopic - Reduced dimensionality
# 2022-11-08 08:00:36,127 - BERTopic - Clustered reduced embeddings
# 2022-11-08 08:00:41,743 - BERTopic - Reduced number of topics from 106 to 31

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Kesimpul**
#
# Bisa Kita lihat hasil dari topic modeling ada bbrapa perbedaan, dalam topic 0 terdapat beberapa kata seperti 'dog', 'food', 'dogs' 'and' 'my'. sehingga terlihat kata yang memiliki peluang muncul terbesar pada topic 0 adalah makanan dog/anjing. Kemudian untuk topic 1, dan kata 'chocolate' memiliki peluang terbesar dalam topik 1, dan juga terdapat beberapa kata seperti 'cocoa'.
#
# Pada topic ke 2 peluang yang sering muncul adalah 'chips', topic ke 3 peluang yang sering muncul adalah 'tea' dan pada topic ke 4 adalah 'cookies'. dan terlihat bahwa peluang terbanyak yang sering di beli oleh konsumen adalah ships, tea dan juga cookies pada topic ke 2, 3 dan 4.
#
# Kemudian pada topic ke 5 peluang tertinggi yang banyak di beli konsumen adalah gluten kemudian setelah itu ada bisquick, dan pancakes.kemudian pada topic ke 6 yang memiliki peluang paling tinggi adalah coffe. terlihat cofee muncul paling tinggi dan termasuk yang sering di minati oleh konsumen.
